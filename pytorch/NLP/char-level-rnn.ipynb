# %% [markdown]
# # Character-Level LSTM in PyTorch
#
# Character-level LSTM with PyTorch. The network will train character by character on some text, then generate new text character by character. As an example, I will train on Anna Karenina.
#
# This network is based off of Andrej Karpathy's [post on RNNs](http://karpathy.github.io/2015/05/21/rnn-effectiveness/) and [implementation in Torch](https://github.com/karpathy/char-rnn). Below is the general architecture of the character-wise RNN.

# %%
import numpy as np
import torch
from torch import nn
import torch.nn.functional as F

# %% [markdown]
# ## Loading Data

# %%
# open text file and read in data as `text`
with open('anna.txt', 'r') as f:
    text = f.read()

# %%
# view sample data
text[:100]
# Out:
# 'Chapter 1\n\n\nHappy families are all alike; every unhappy family is unhappy in its own\nway.\n\nEverythin'

# %% [markdown]
# ## Tokenization

# %%
# encode the text and map each character to an integer and vice versa

# we create two dictionaries:
# 1. int2char, which maps integers to characters
# 2. char2int, which maps characters to unique integers
chars = tuple(set(text))
int2char = dict(enumerate(chars))
char2int = {ch: ii for ii, ch in int2char.items()}

# encode the text
encoded = np.array([char2int[ch] for ch in text])

# %%
# same data but in integer format
encoded[:100]
# Out:
# array([13, 57, 77, 33, 82, 22, 80, 42, 66, 12, 12, 12, 51, 77, 33, 33, 32,
#        42, 75, 77, 71, 14, 34, 14, 22, 21, 42, 77, 80, 22, 42, 77, 34, 34,
#        42, 77, 34, 14, 39, 22, 10, 42, 22, 45, 22, 80, 32, 42, 69, 43, 57,
#        77, 33, 33, 32, 42, 75, 77, 71, 14, 34, 32, 42, 14, 21, 42, 69, 43,
#        57, 77, 33, 33, 32, 42, 14, 43, 42, 14, 82, 21, 42, 63, 37, 43, 12,
#        37, 77, 32, 54, 12, 12, 60, 45, 22, 80, 32, 82, 57, 14, 43])

# %% [markdown]
# ## Pre-processing Data

# %%
def one_hot_encode(arr, n_labels):
    
    # Initialize the the encoded array
    one_hot = np.zeros((arr.size, n_labels), dtype=np.float32)
    
    # Fill the appropriate elements with ones
    one_hot[np.arange(one_hot.shape[0]), arr.flatten()] = 1.
    
    # Finally reshape it to get back to the original array
    one_hot = one_hot.reshape((*arr.shape, n_labels))
    
    return one_hot

# %%
def get_batches(arr, batch_size, seq_length):
    '''Create a generator that returns batches of size
       batch_size x seq_length from arr.
       
       Arguments
       ---------
       arr: Array you want to make batches from
       batch_size: Batch size, the number of sequences per batch
       seq_length: Number of encoded chars in a sequence
    '''
    
    batch_size_total = batch_size * seq_length
    # total number of batches we can make
    n_batches = len(arr)//batch_size_total
    
    # Keep only enough characters to make full batches
    arr = arr[:n_batches * batch_size_total]
    # Reshape into batch_size rows
    arr = arr.reshape((batch_size, -1))
    
    # iterate through the array, one sequence at a time
    for n in range(0, arr.shape[1], seq_length):
        # The features
        x = arr[:, n:n+seq_length]
        # The targets, shifted by one
        y = np.zeros_like(x)
        try:
            y[:, :-1], y[:, -1] = x[:, 1:], arr[:, n+seq_length]
        except IndexError:
            y[:, :-1], y[:, -1] = x[:, 1:], arr[:, 0]
        yield x, y

# %% [markdown]
# ## Training Network

# %%
# check if GPU is available
train_on_gpu = torch.cuda.is_available()
if(train_on_gpu):
    print('Training on GPU!')
else: 
    print('No GPU available, training on CPU; consider making n_epochs very small.')
# Out:
# Training on GPU!

# %%
class CharRNN(nn.Module):
    
    def __init__(self, tokens, n_hidden=256, n_layers=2,
                               drop_prob=0.5, lr=0.001):
        super().__init__()
        self.drop_prob = drop_prob
        self.n_layers = n_layers
        self.n_hidden = n_hidden
        self.lr = lr
        
        # creating character dictionaries
        self.chars = tokens
        self.int2char = dict(enumerate(self.chars))
        self.char2int = {ch: ii for ii, ch in self.int2char.items()}
        
        ## TODO: define the LSTM
        self.lstm = nn.LSTM(len(self.chars), n_hidden, n_layers, 
                            dropout=drop_prob, batch_first=True)
        
        ## TODO: define a dropout layer
        self.dropout = nn.Dropout(drop_prob)
        
        ## TODO: define the final, fully-connected output layer
        self.fc = nn.Linear(n_hidden, len(self.chars))
      
    
    def forward(self, x, hidden):
        ''' Forward pass through the network. 
            These inputs are x, and the hidden/cell state `hidden`. '''
                
        ## TODO: Get the outputs and the new hidden state from the lstm
        r_output, hidden = self.lstm(x, hidden)
        
        ## TODO: pass through a dropout layer
        out = self.dropout(r_output)
        
        # Stack up LSTM outputs using view
        # you may need to use contiguous to reshape the output
        out = out.contiguous().view(-1, self.n_hidden)
        
        ## TODO: put x through the fully-connected layer
        out = self.fc(out)
        
        # return the final output and the hidden state
        return out, hidden
    
    
    def init_hidden(self, batch_size):
        ''' Initializes hidden state '''
        # Create two new tensors with sizes n_layers x batch_size x n_hidden,
        # initialized to zero, for hidden state and cell state of LSTM
        weight = next(self.parameters()).data
        
        if (train_on_gpu):
            hidden = (weight.new(self.n_layers, batch_size, self.n_hidden).zero_().cuda(),
                  weight.new(self.n_layers, batch_size, self.n_hidden).zero_().cuda())
        else:
            hidden = (weight.new(self.n_layers, batch_size, self.n_hidden).zero_(),
                      weight.new(self.n_layers, batch_size, self.n_hidden).zero_())
        
        return hidden

# %%
def train(net, data, epochs=10, batch_size=10, seq_length=50, lr=0.001, clip=5, val_frac=0.1, print_every=10):
    ''' Training a network 
    
        Arguments
        ---------
        
        net: CharRNN network
        data: text data to train the network
        epochs: Number of epochs to train
        batch_size: Number of mini-sequences per mini-batch, aka batch size
        seq_length: Number of character steps per mini-batch
        lr: learning rate
        clip: gradient clipping
        val_frac: Fraction of data to hold out for validation
        print_every: Number of steps for printing training and validation loss
    
    '''
    net.train()
    
    opt = torch.optim.Adam(net.parameters(), lr=lr)
    criterion = nn.CrossEntropyLoss()
    
    # create training and validation data
    val_idx = int(len(data)*(1-val_frac))
    data, val_data = data[:val_idx], data[val_idx:]
    
    if(train_on_gpu):
        net.cuda()
    
    counter = 0
    n_chars = len(net.chars)
    for e in range(epochs):
        # initialize hidden state
        h = net.init_hidden(batch_size)
        
        for x, y in get_batches(data, batch_size, seq_length):
            counter += 1
            
            # One-hot encode our data and make them Torch tensors
            x = one_hot_encode(x, n_chars)
            inputs, targets = torch.from_numpy(x), torch.from_numpy(y)
            
            if(train_on_gpu):
                inputs, targets = inputs.cuda(), targets.cuda()

            # Creating new variables for the hidden state, otherwise
            # we'd backprop through the entire training history
            h = tuple([each.data for each in h])

            # zero accumulated gradients
            net.zero_grad()
            
            # get the output from the model
            output, h = net(inputs, h)
            
            # calculate the loss and perform backprop
            loss = criterion(output, targets.view(batch_size*seq_length).long())
            loss.backward()
            # `clip_grad_norm` helps prevent the exploding gradient problem in RNNs / LSTMs.
            nn.utils.clip_grad_norm_(net.parameters(), clip)
            opt.step()
            
            # loss stats
            if counter % print_every == 0:
                # Get validation loss
                val_h = net.init_hidden(batch_size)
                val_losses = []
                net.eval()
                for x, y in get_batches(val_data, batch_size, seq_length):
                    # One-hot encode our data and make them Torch tensors
                    x = one_hot_encode(x, n_chars)
                    x, y = torch.from_numpy(x), torch.from_numpy(y)
                    
                    # Creating new variables for the hidden state, otherwise
                    # we'd backprop through the entire training history
                    val_h = tuple([each.data for each in val_h])
                    
                    inputs, targets = x, y
                    if(train_on_gpu):
                        inputs, targets = inputs.cuda(), targets.cuda()

                    output, val_h = net(inputs, val_h)
                    val_loss = criterion(output, targets.view(batch_size*seq_length).long())
                
                    val_losses.append(val_loss.item())
                
                net.train() # reset to train mode after iterationg through validation data
                
                print("Epoch: {}/{}...".format(e+1, epochs),
                      "Step: {}...".format(counter),
                      "Loss: {:.4f}...".format(loss.item()),
                      "Val Loss: {:.4f}".format(np.mean(val_losses)))

# %% [markdown]
# ## Instantiate the Model

# %%
# define and print the net
n_hidden=512
n_layers=2

net = CharRNN(chars, n_hidden, n_layers)
print(net)
# Out:
# CharRNN(
#   (lstm): LSTM(83, 512, num_layers=2, batch_first=True, dropout=0.5)
#   (dropout): Dropout(p=0.5, inplace=False)
#   (fc): Linear(in_features=512, out_features=83, bias=True)
# )

# %% [markdown]
# ## Training the Model

# %%
batch_size = 128
seq_length = 100
n_epochs = 20 # start smaller if you are just testing initial behavior

# train the model
train(net, encoded, epochs=n_epochs, batch_size=batch_size, seq_length=seq_length, lr=0.001, print_every=10)
# Out:
# Epoch: 1/20... Step: 10... Loss: 3.2649... Val Loss: 3.2010
# Epoch: 1/20... Step: 20... Loss: 3.1556... Val Loss: 3.1324
# Epoch: 1/20... Step: 30... Loss: 3.1443... Val Loss: 3.1225
# Epoch: 1/20... Step: 40... Loss: 3.1177... Val Loss: 3.1196
# Epoch: 1/20... Step: 50... Loss: 3.1459... Val Loss: 3.1178
# Epoch: 1/20... Step: 60... Loss: 3.1197... Val Loss: 3.1166
# Epoch: 1/20... Step: 70... Loss: 3.1136... Val Loss: 3.1159
# Epoch: 1/20... Step: 80... Loss: 3.1260... Val Loss: 3.1138
# Epoch: 1/20... Step: 90... Loss: 3.1246... Val Loss: 3.1091
# Epoch: 1/20... Step: 100... Loss: 3.1080... Val Loss: 3.0995
# Epoch: 1/20... Step: 110... Loss: 3.0862... Val Loss: 3.0739
# Epoch: 1/20... Step: 120... Loss: 3.0226... Val Loss: 3.0158
# Epoch: 1/20... Step: 130... Loss: 2.9508... Val Loss: 2.9412
# Epoch: 2/20... Step: 140... Loss: 2.9076... Val Loss: 2.8653
# Epoch: 2/20... Step: 150... Loss: 2.7824... Val Loss: 2.7403
# Epoch: 2/20... Step: 160... Loss: 2.6750... Val Loss: 2.6307
# Epoch: 2/20... Step: 170... Loss: 2.5594... Val Loss: 2.5411
# Epoch: 2/20... Step: 180... Loss: 2.5160... Val Loss: 2.4904
# Epoch: 2/20... Step: 190... Loss: 2.4582... Val Loss: 2.4455
# Epoch: 2/20... Step: 200... Loss: 2.4486... Val Loss: 2.4222
# Epoch: 2/20... Step: 210... Loss: 2.4264... Val Loss: 2.3815
# Epoch: 2/20... Step: 220... Loss: 2.3792... Val Loss: 2.3520
# Epoch: 2/20... Step: 230... Loss: 2.3565... Val Loss: 2.3218
# Epoch: 2/20... Step: 240... Loss: 2.3363... Val Loss: 2.3010
# Epoch: 2/20... Step: 250... Loss: 2.2763... Val Loss: 2.2723
# Epoch: 2/20... Step: 260... Loss: 2.2549... Val Loss: 2.2480
# Epoch: 2/20... Step: 270... Loss: 2.2530... Val Loss: 2.2182
# Epoch: 3/20... Step: 280... Loss: 2.2498... Val Loss: 2.2055
# Epoch: 3/20... Step: 290... Loss: 2.2059... Val Loss: 2.1733
# Epoch: 3/20... Step: 300... Loss: 2.1860... Val Loss: 2.1504
# Epoch: 3/20... Step: 310... Loss: 2.1630... Val Loss: 2.1316
# Epoch: 3/20... Step: 320... Loss: 2.1366... Val Loss: 2.1089
# Epoch: 3/20... Step: 330... Loss: 2.1074... Val Loss: 2.0975
# Epoch: 3/20... Step: 340... Loss: 2.1178... Val Loss: 2.0712
# Epoch: 3/20... Step: 350... Loss: 2.1047... Val Loss: 2.0536
# Epoch: 3/20... Step: 360... Loss: 2.0290... Val Loss: 2.0355
# Epoch: 3/20... Step: 370... Loss: 2.0600... Val Loss: 2.0155
# Epoch: 3/20... Step: 380... Loss: 2.0332... Val Loss: 2.0029
# Epoch: 3/20... Step: 390... Loss: 2.0136... Val Loss: 1.9885
# Epoch: 3/20... Step: 400... Loss: 1.9828... Val Loss: 1.9724
# Epoch: 3/20... Step: 410... Loss: 1.9885... Val Loss: 1.9542
# Epoch: 4/20... Step: 420... Loss: 1.9750... Val Loss: 1.9391
# Epoch: 4/20... Step: 430... Loss: 1.9627... Val Loss: 1.9208
# Epoch: 4/20... Step: 440... Loss: 1.9385... Val Loss: 1.9105
# Epoch: 4/20... Step: 450... Loss: 1.8872... Val Loss: 1.8919
# Epoch: 4/20... Step: 460... Loss: 1.8729... Val Loss: 1.8815
# Epoch: 4/20... Step: 470... Loss: 1.9093... Val Loss: 1.8740
# Epoch: 4/20... Step: 480... Loss: 1.8856... Val Loss: 1.8625
# Epoch: 4/20... Step: 490... Loss: 1.8862... Val Loss: 1.8439
# Epoch: 4/20... Step: 500... Loss: 1.8793... Val Loss: 1.8289
# Epoch: 4/20... Step: 510... Loss: 1.8523... Val Loss: 1.8169
# Epoch: 4/20... Step: 520... Loss: 1.8651... Val Loss: 1.8061
# Epoch: 4/20... Step: 530... Loss: 1.8236... Val Loss: 1.7943
# Epoch: 4/20... Step: 540... Loss: 1.7801... Val Loss: 1.7857
# Epoch: 4/20... Step: 550... Loss: 1.8368... Val Loss: 1.7709
# Epoch: 5/20... Step: 560... Loss: 1.7965... Val Loss: 1.7635
# Epoch: 5/20... Step: 570... Loss: 1.7802... Val Loss: 1.7510
# Epoch: 5/20... Step: 580... Loss: 1.7599... Val Loss: 1.7443
# Epoch: 5/20... Step: 590... Loss: 1.7677... Val Loss: 1.7351
# Epoch: 5/20... Step: 600... Loss: 1.7343... Val Loss: 1.7264
# Epoch: 5/20... Step: 610... Loss: 1.7415... Val Loss: 1.7193
# Epoch: 5/20... Step: 620... Loss: 1.7366... Val Loss: 1.7083
# Epoch: 5/20... Step: 630... Loss: 1.7444... Val Loss: 1.7000
# Epoch: 5/20... Step: 640... Loss: 1.7161... Val Loss: 1.6920
# Epoch: 5/20... Step: 650... Loss: 1.7119... Val Loss: 1.6848
# Epoch: 5/20... Step: 660... Loss: 1.6821... Val Loss: 1.6802
# Epoch: 5/20... Step: 670... Loss: 1.7101... Val Loss: 1.6725
# Epoch: 5/20... Step: 680... Loss: 1.7076... Val Loss: 1.6635
# Epoch: 5/20... Step: 690... Loss: 1.6808... Val Loss: 1.6587
# Epoch: 6/20... Step: 700... Loss: 1.6759... Val Loss: 1.6508
# Epoch: 6/20... Step: 710... Loss: 1.6693... Val Loss: 1.6406
# Epoch: 6/20... Step: 720... Loss: 1.6498... Val Loss: 1.6341
# Epoch: 6/20... Step: 730... Loss: 1.6610... Val Loss: 1.6337
# Epoch: 6/20... Step: 740... Loss: 1.6356... Val Loss: 1.6261
# Epoch: 6/20... Step: 750... Loss: 1.6143... Val Loss: 1.6196
# Epoch: 6/20... Step: 760... Loss: 1.6489... Val Loss: 1.6134
# Epoch: 6/20... Step: 770... Loss: 1.6339... Val Loss: 1.6125
# Epoch: 6/20... Step: 780... Loss: 1.6194... Val Loss: 1.6030
# Epoch: 6/20... Step: 790... Loss: 1.6003... Val Loss: 1.5976
# Epoch: 6/20... Step: 800... Loss: 1.6200... Val Loss: 1.5961
# Epoch: 6/20... Step: 810... Loss: 1.6013... Val Loss: 1.5848
# Epoch: 6/20... Step: 820... Loss: 1.5632... Val Loss: 1.5830
# Epoch: 6/20... Step: 830... Loss: 1.6136... Val Loss: 1.5796
# Epoch: 7/20... Step: 840... Loss: 1.5706... Val Loss: 1.5746
# Epoch: 7/20... Step: 850... Loss: 1.5903... Val Loss: 1.5668
# Epoch: 7/20... Step: 860... Loss: 1.5697... Val Loss: 1.5624
# Epoch: 7/20... Step: 870... Loss: 1.5737... Val Loss: 1.5592
# Epoch: 7/20... Step: 880... Loss: 1.5791... Val Loss: 1.5553
# Epoch: 7/20... Step: 890... Loss: 1.5829... Val Loss: 1.5514
# Epoch: 7/20... Step: 900... Loss: 1.5604... Val Loss: 1.5476
# Epoch: 7/20... Step: 910... Loss: 1.5301... Val Loss: 1.5466
# Epoch: 7/20... Step: 920... Loss: 1.5508... Val Loss: 1.5398
# Epoch: 7/20... Step: 930... Loss: 1.5332... Val Loss: 1.5343
# Epoch: 7/20... Step: 940... Loss: 1.5424... Val Loss: 1.5322
# Epoch: 7/20... Step: 950... Loss: 1.5463... Val Loss: 1.5292
# Epoch: 7/20... Step: 960... Loss: 1.5407... Val Loss: 1.5239
# Epoch: 7/20... Step: 970... Loss: 1.5561... Val Loss: 1.5203
# Epoch: 8/20... Step: 980... Loss: 1.5207... Val Loss: 1.5218
# Epoch: 8/20... Step: 990... Loss: 1.5249... Val Loss: 1.5128
# Epoch: 8/20... Step: 1000... Loss: 1.5127... Val Loss: 1.5067
# Epoch: 8/20... Step: 1010... Loss: 1.5628... Val Loss: 1.5059
# Epoch: 8/20... Step: 1020... Loss: 1.5226... Val Loss: 1.5044
# Epoch: 8/20... Step: 1030... Loss: 1.4973... Val Loss: 1.5013
# Epoch: 8/20... Step: 1040... Loss: 1.5126... Val Loss: 1.5016
# Epoch: 8/20... Step: 1050... Loss: 1.4945... Val Loss: 1.4975
# Epoch: 8/20... Step: 1060... Loss: 1.4958... Val Loss: 1.4926
# Epoch: 8/20... Step: 1070... Loss: 1.5032... Val Loss: 1.4874
# Epoch: 8/20... Step: 1080... Loss: 1.4909... Val Loss: 1.4874
# Epoch: 8/20... Step: 1090... Loss: 1.4801... Val Loss: 1.4819
# Epoch: 8/20... Step: 1100... Loss: 1.4729... Val Loss: 1.4789
# Epoch: 8/20... Step: 1110... Loss: 1.4856... Val Loss: 1.4789
# Epoch: 9/20... Step: 1120... Loss: 1.4871... Val Loss: 1.4792
# Epoch: 9/20... Step: 1130... Loss: 1.4872... Val Loss: 1.4708
# Epoch: 9/20... Step: 1140... Loss: 1.4855... Val Loss: 1.4677
# Epoch: 9/20... Step: 1150... Loss: 1.5004... Val Loss: 1.4700
# Epoch: 9/20... Step: 1160... Loss: 1.4586... Val Loss: 1.4636
# Epoch: 9/20... Step: 1170... Loss: 1.4588... Val Loss: 1.4610
# Epoch: 9/20... Step: 1180... Loss: 1.4576... Val Loss: 1.4608
# Epoch: 9/20... Step: 1190... Loss: 1.4910... Val Loss: 1.4567
# Epoch: 9/20... Step: 1200... Loss: 1.4483... Val Loss: 1.4578
# Epoch: 9/20... Step: 1210... Loss: 1.4571... Val Loss: 1.4495
# Epoch: 9/20... Step: 1220... Loss: 1.4564... Val Loss: 1.4508
# Epoch: 9/20... Step: 1230... Loss: 1.4337... Val Loss: 1.4511
# Epoch: 9/20... Step: 1240... Loss: 1.4352... Val Loss: 1.4448
# Epoch: 9/20... Step: 1250... Loss: 1.4516... Val Loss: 1.4424
# Epoch: 10/20... Step: 1260... Loss: 1.4537... Val Loss: 1.4409
# Epoch: 10/20... Step: 1270... Loss: 1.4415... Val Loss: 1.4386
# Epoch: 10/20... Step: 1280... Loss: 1.4578... Val Loss: 1.4348
# Epoch: 10/20... Step: 1290... Loss: 1.4419... Val Loss: 1.4366
# Epoch: 10/20... Step: 1300... Loss: 1.4312... Val Loss: 1.4300
# Epoch: 10/20... Step: 1310... Loss: 1.4402... Val Loss: 1.4329
# Epoch: 10/20... Step: 1320... Loss: 1.4082... Val Loss: 1.4338
# Epoch: 10/20... Step: 1330... Loss: 1.4121... Val Loss: 1.4263
# Epoch: 10/20... Step: 1340... Loss: 1.3978... Val Loss: 1.4246
# Epoch: 10/20... Step: 1350... Loss: 1.3965... Val Loss: 1.4202
# Epoch: 10/20... Step: 1360... Loss: 1.4063... Val Loss: 1.4251
# Epoch: 10/20... Step: 1370... Loss: 1.3836... Val Loss: 1.4192
# Epoch: 10/20... Step: 1380... Loss: 1.4340... Val Loss: 1.4163
# Epoch: 10/20... Step: 1390... Loss: 1.4411... Val Loss: 1.4150
# Epoch: 11/20... Step: 1400... Loss: 1.4330... Val Loss: 1.4129
# Epoch: 11/20... Step: 1410... Loss: 1.4486... Val Loss: 1.4094
# Epoch: 11/20... Step: 1420... Loss: 1.4296... Val Loss: 1.4057
# Epoch: 11/20... Step: 1430... Loss: 1.4081... Val Loss: 1.4124
# Epoch: 11/20... Step: 1440... Loss: 1.4316... Val Loss: 1.4051
# Epoch: 11/20... Step: 1450... Loss: 1.3631... Val Loss: 1.4061
# Epoch: 11/20... Step: 1460... Loss: 1.3840... Val Loss: 1.4020
# Epoch: 11/20... Step: 1470... Loss: 1.3745... Val Loss: 1.4009
# Epoch: 11/20... Step: 1480... Loss: 1.3876... Val Loss: 1.3961
# Epoch: 11/20... Step: 1490... Loss: 1.3848... Val Loss: 1.3987
# Epoch: 11/20... Step: 1500... Loss: 1.3660... Val Loss: 1.3974
# Epoch: 11/20... Step: 1510... Loss: 1.3502... Val Loss: 1.3981
# Epoch: 11/20... Step: 1520... Loss: 1.3903... Val Loss: 1.3935
# Epoch: 12/20... Step: 1530... Loss: 1.4493... Val Loss: 1.3930
# Epoch: 12/20... Step: 1540... Loss: 1.3958... Val Loss: 1.3912
# Epoch: 12/20... Step: 1550... Loss: 1.4006... Val Loss: 1.3895
# Epoch: 12/20... Step: 1560... Loss: 1.4135... Val Loss: 1.3865
# Epoch: 12/20... Step: 1570... Loss: 1.3607... Val Loss: 1.3926
# Epoch: 12/20... Step: 1580... Loss: 1.3391... Val Loss: 1.3877
# Epoch: 12/20... Step: 1590... Loss: 1.3329... Val Loss: 1.3881
# Epoch: 12/20... Step: 1600... Loss: 1.3605... Val Loss: 1.3810
# Epoch: 12/20... Step: 1610... Loss: 1.3532... Val Loss: 1.3842
# Epoch: 12/20... Step: 1620... Loss: 1.3563... Val Loss: 1.3825
# Epoch: 12/20... Step: 1630... Loss: 1.3735... Val Loss: 1.3778
# Epoch: 12/20... Step: 1640... Loss: 1.3528... Val Loss: 1.3786
# Epoch: 12/20... Step: 1650... Loss: 1.3227... Val Loss: 1.3817
# Epoch: 12/20... Step: 1660... Loss: 1.3875... Val Loss: 1.3776
# Epoch: 13/20... Step: 1670... Loss: 1.3483... Val Loss: 1.3769
# Epoch: 13/20... Step: 1680... Loss: 1.3682... Val Loss: 1.3730
# Epoch: 13/20... Step: 1690... Loss: 1.3498... Val Loss: 1.3708
# Epoch: 13/20... Step: 1700... Loss: 1.3414... Val Loss: 1.3683
# Epoch: 13/20... Step: 1710... Loss: 1.3275... Val Loss: 1.3772
# Epoch: 13/20... Step: 1720... Loss: 1.3373... Val Loss: 1.3700
# Epoch: 13/20... Step: 1730... Loss: 1.3761... Val Loss: 1.3681
# Epoch: 13/20... Step: 1740... Loss: 1.3344... Val Loss: 1.3661
# Epoch: 13/20... Step: 1750... Loss: 1.2974... Val Loss: 1.3697
# Epoch: 13/20... Step: 1760... Loss: 1.3302... Val Loss: 1.3635
# Epoch: 13/20... Step: 1770... Loss: 1.3446... Val Loss: 1.3639
# Epoch: 13/20... Step: 1780... Loss: 1.3225... Val Loss: 1.3625
# Epoch: 13/20... Step: 1790... Loss: 1.3150... Val Loss: 1.3639
# Epoch: 13/20... Step: 1800... Loss: 1.3368... Val Loss: 1.3632
# Epoch: 14/20... Step: 1810... Loss: 1.3455... Val Loss: 1.3600
# Epoch: 14/20... Step: 1820... Loss: 1.3320... Val Loss: 1.3586
# Epoch: 14/20... Step: 1830... Loss: 1.3488... Val Loss: 1.3559
# Epoch: 14/20... Step: 1840... Loss: 1.2924... Val Loss: 1.3550
# Epoch: 14/20... Step: 1850... Loss: 1.2830... Val Loss: 1.3560
# Epoch: 14/20... Step: 1860... Loss: 1.3375... Val Loss: 1.3550
# Epoch: 14/20... Step: 1870... Loss: 1.3409... Val Loss: 1.3558
# Epoch: 14/20... Step: 1880... Loss: 1.3334... Val Loss: 1.3506
# Epoch: 14/20... Step: 1890... Loss: 1.3560... Val Loss: 1.3587
# Epoch: 14/20... Step: 1900... Loss: 1.3259... Val Loss: 1.3506
# Epoch: 14/20... Step: 1910... Loss: 1.3309... Val Loss: 1.3497
# Epoch: 14/20... Step: 1920... Loss: 1.3217... Val Loss: 1.3509
# Epoch: 14/20... Step: 1930... Loss: 1.2871... Val Loss: 1.3488
# Epoch: 14/20... Step: 1940... Loss: 1.3472... Val Loss: 1.3469
# Epoch: 15/20... Step: 1950... Loss: 1.3109... Val Loss: 1.3482
# Epoch: 15/20... Step: 1960... Loss: 1.3126... Val Loss: 1.3459
# Epoch: 15/20... Step: 1970... Loss: 1.3019... Val Loss: 1.3425
# Epoch: 15/20... Step: 1980... Loss: 1.2933... Val Loss: 1.3430
# Epoch: 15/20... Step: 1990... Loss: 1.3059... Val Loss: 1.3437
# Epoch: 15/20... Step: 2000... Loss: 1.2897... Val Loss: 1.3410
# Epoch: 15/20... Step: 2010... Loss: 1.3089... Val Loss: 1.3381
# Epoch: 15/20... Step: 2020... Loss: 1.3104... Val Loss: 1.3385
# Epoch: 15/20... Step: 2030... Loss: 1.2905... Val Loss: 1.3402
# Epoch: 15/20... Step: 2040... Loss: 1.3109... Val Loss: 1.3364
# Epoch: 15/20... Step: 2050... Loss: 1.2863... Val Loss: 1.3355
# Epoch: 15/20... Step: 2060... Loss: 1.3052... Val Loss: 1.3380
# Epoch: 15/20... Step: 2070... Loss: 1.3084... Val Loss: 1.3329
# Epoch: 15/20... Step: 2080... Loss: 1.3046... Val Loss: 1.3324
# Epoch: 16/20... Step: 2090... Loss: 1.3121... Val Loss: 1.3398
# Epoch: 16/20... Step: 2100... Loss: 1.2799... Val Loss: 1.3262
# Epoch: 16/20... Step: 2110... Loss: 1.2838... Val Loss: 1.3248
# Epoch: 16/20... Step: 2120... Loss: 1.2939... Val Loss: 1.3266
# Epoch: 16/20... Step: 2130... Loss: 1.2651... Val Loss: 1.3238
# Epoch: 16/20... Step: 2140... Loss: 1.2822... Val Loss: 1.3255
# Epoch: 16/20... Step: 2150... Loss: 1.2945... Val Loss: 1.3246
# Epoch: 16/20... Step: 2160... Loss: 1.2877... Val Loss: 1.3225
# Epoch: 16/20... Step: 2170... Loss: 1.2706... Val Loss: 1.3259
# Epoch: 16/20... Step: 2180... Loss: 1.2695... Val Loss: 1.3200
# Epoch: 16/20... Step: 2190... Loss: 1.3004... Val Loss: 1.3220
# Epoch: 16/20... Step: 2200... Loss: 1.2779... Val Loss: 1.3241
# Epoch: 16/20... Step: 2210... Loss: 1.2348... Val Loss: 1.3221
# Epoch: 16/20... Step: 2220... Loss: 1.2811... Val Loss: 1.3213
# Epoch: 17/20... Step: 2230... Loss: 1.2634... Val Loss: 1.3170
# Epoch: 17/20... Step: 2240... Loss: 1.2678... Val Loss: 1.3163
# Epoch: 17/20... Step: 2250... Loss: 1.2504... Val Loss: 1.3118
# Epoch: 17/20... Step: 2260... Loss: 1.2579... Val Loss: 1.3132
# Epoch: 17/20... Step: 2270... Loss: 1.2697... Val Loss: 1.3136
# Epoch: 17/20... Step: 2280... Loss: 1.2802... Val Loss: 1.3102
# Epoch: 17/20... Step: 2290... Loss: 1.2692... Val Loss: 1.3133
# Epoch: 17/20... Step: 2300... Loss: 1.2421... Val Loss: 1.3105
# Epoch: 17/20... Step: 2310... Loss: 1.2608... Val Loss: 1.3132
# Epoch: 17/20... Step: 2320... Loss: 1.2534... Val Loss: 1.3060
# Epoch: 17/20... Step: 2330... Loss: 1.2542... Val Loss: 1.3059
# Epoch: 17/20... Step: 2340... Loss: 1.2651... Val Loss: 1.3103
# Epoch: 17/20... Step: 2350... Loss: 1.2688... Val Loss: 1.3037
# Epoch: 17/20... Step: 2360... Loss: 1.2720... Val Loss: 1.3040
# Epoch: 18/20... Step: 2370... Loss: 1.2468... Val Loss: 1.3009
# Epoch: 18/20... Step: 2380... Loss: 1.2545... Val Loss: 1.2999
# Epoch: 18/20... Step: 2390... Loss: 1.2361... Val Loss: 1.3017
# Epoch: 18/20... Step: 2400... Loss: 1.2739... Val Loss: 1.3007
# Epoch: 18/20... Step: 2410... Loss: 1.2674... Val Loss: 1.2964
# Epoch: 18/20... Step: 2420... Loss: 1.2451... Val Loss: 1.3004
# Epoch: 18/20... Step: 2430... Loss: 1.2501... Val Loss: 1.3004
# Epoch: 18/20... Step: 2440... Loss: 1.2341... Val Loss: 1.2962
# Epoch: 18/20... Step: 2450... Loss: 1.2332... Val Loss: 1.2969
# Epoch: 18/20... Step: 2460... Loss: 1.2588... Val Loss: 1.2915
# Epoch: 18/20... Step: 2470... Loss: 1.2527... Val Loss: 1.2952
# Epoch: 18/20... Step: 2480... Loss: 1.2375... Val Loss: 1.3005
# Epoch: 18/20... Step: 2490... Loss: 1.2268... Val Loss: 1.2908
# Epoch: 18/20... Step: 2500... Loss: 1.2347... Val Loss: 1.2936
# Epoch: 19/20... Step: 2510... Loss: 1.2349... Val Loss: 1.2905
# Epoch: 19/20... Step: 2520... Loss: 1.2473... Val Loss: 1.2902
# Epoch: 19/20... Step: 2530... Loss: 1.2522... Val Loss: 1.2948
# Epoch: 19/20... Step: 2540... Loss: 1.2662... Val Loss: 1.2891
# Epoch: 19/20... Step: 2550... Loss: 1.2258... Val Loss: 1.2907
# Epoch: 19/20... Step: 2560... Loss: 1.2386... Val Loss: 1.2919
# Epoch: 19/20... Step: 2570... Loss: 1.2233... Val Loss: 1.2939
# Epoch: 19/20... Step: 2580... Loss: 1.2639... Val Loss: 1.2856
# Epoch: 19/20... Step: 2590... Loss: 1.2127... Val Loss: 1.2883
# Epoch: 19/20... Step: 2600... Loss: 1.2265... Val Loss: 1.2854
# Epoch: 19/20... Step: 2610... Loss: 1.2351... Val Loss: 1.2883
# Epoch: 19/20... Step: 2620... Loss: 1.2144... Val Loss: 1.2877
# Epoch: 19/20... Step: 2630... Loss: 1.2182... Val Loss: 1.2885
# Epoch: 19/20... Step: 2640... Loss: 1.2316... Val Loss: 1.2842
# Epoch: 20/20... Step: 2650... Loss: 1.2312... Val Loss: 1.2800
# Epoch: 20/20... Step: 2660... Loss: 1.2301... Val Loss: 1.2802
# Epoch: 20/20... Step: 2670... Loss: 1.2501... Val Loss: 1.2878
# Epoch: 20/20... Step: 2680... Loss: 1.2380... Val Loss: 1.2818
# Epoch: 20/20... Step: 2690... Loss: 1.2259... Val Loss: 1.2792
# Epoch: 20/20... Step: 2700... Loss: 1.2313... Val Loss: 1.2754
# Epoch: 20/20... Step: 2710... Loss: 1.1973... Val Loss: 1.2781
# Epoch: 20/20... Step: 2720... Loss: 1.2114... Val Loss: 1.2764
# Epoch: 20/20... Step: 2730... Loss: 1.2008... Val Loss: 1.2813
# Epoch: 20/20... Step: 2740... Loss: 1.2055... Val Loss: 1.2810
# Epoch: 20/20... Step: 2750... Loss: 1.2061... Val Loss: 1.2803
# Epoch: 20/20... Step: 2760... Loss: 1.1915... Val Loss: 1.2791
# Epoch: 20/20... Step: 2770... Loss: 1.2333... Val Loss: 1.2752
# Epoch: 20/20... Step: 2780... Loss: 1.2616... Val Loss: 1.2733

# %% [markdown]
# ## Save Model Checkpoint

# %%
# change the name, for saving multiple files
model_name = 'rnn_20_epoch.net'

checkpoint = {'n_hidden': net.n_hidden,
              'n_layers': net.n_layers,
              'state_dict': net.state_dict(),
              'tokens': net.chars}

with open(model_name, 'wb') as f:
    torch.save(checkpoint, f)

# %% [markdown]
# ## Predict

# %%
def predict(net, char, h=None, top_k=None):
        ''' Given a character, predict the next character.
            Returns the predicted character and the hidden state.
        '''
        
        # tensor inputs
        x = np.array([[net.char2int[char]]])
        x = one_hot_encode(x, len(net.chars))
        inputs = torch.from_numpy(x)
        
        if(train_on_gpu):
            inputs = inputs.cuda()
        
        # detach hidden state from history
        h = tuple([each.data for each in h])
        # get the output of the model
        out, h = net(inputs, h)

        # get the character probabilities
        p = F.softmax(out, dim=1).data
        if(train_on_gpu):
            p = p.cpu() # move to cpu
        
        # get top characters
        if top_k is None:
            top_ch = np.arange(len(net.chars))
        else:
            p, top_ch = p.topk(top_k)
            top_ch = top_ch.numpy().squeeze()
        
        # select the likely next character with some element of randomness
        p = p.numpy().squeeze()
        char = np.random.choice(top_ch, p=p/p.sum())
        
        # return the encoded value of the predicted char and the hidden state
        return net.int2char[char], h

# %%
def sample(net, size, prime='The', top_k=None):
        
    if(train_on_gpu):
        net.cuda()
    else:
        net.cpu()
    
    net.eval() # eval mode
    
    # First off, run through the prime characters
    chars = [ch for ch in prime]
    h = net.init_hidden(1)
    for ch in prime:
        char, h = predict(net, ch, h, top_k=top_k)

    chars.append(char)
    
    # Now pass in the previous character and get a new one
    for ii in range(size):
        char, h = predict(net, chars[-1], h, top_k=top_k)
        chars.append(char)

    return ''.join(chars)

# %%
print(sample(net, 1000, prime='Anna', top_k=5))
# Out:
# Anna was, the drawing rouble
# he turned again to her feelings and happy. "I was settled to the
# people of the paper. That's the steps of the sense at once
# the moment, and I won't superver her and that they
# see her tonay. I did not know how it were the face of
# serene.".
#
# "All you to take me," she thought. And the same significat of the
# called thought there always doubts of them out of silence with the
# door attitude to see him all the carriage, but this hand
# to hear any one should say that it was straight at the clearly for
# a carriage. So in a means had stopped. He came to his heaved
# the mannate to him. Taking off ill the charm of her moter, with she
# could not help saying that they were sure so that his soun of
# the painful trace, she had to be to drive to the dreams of
# something that there was always straight on the princess, and whenever she had
# been tried, that she did not know him. Having the
# more stayed.
#
# "Yes, I'm all as have to be to think of the dear in the princess, and I am
# in love to
